# %% [markdown]
# # what is random forest
# * A random forest is a supervised machine learning algorithm that is constructed from decision tree algorithms.
#
#
# * A random forest is a machine learning technique that’s used to solve regression and classification problems. It utilizes       ensemble learning, which is a technique that combines many classifiers to provide solutions to complex problems.
#
#
# * The (random forest) algorithm establishes the outcome based on the predictions of the decision trees. It predicts by taking the average or mean of the output from various trees. Increasing the number of trees increases the precision of the outcome.
#
# **working of Random forest**
# ![rf.png](attachment:712a6b42-1984-4624-88b5-fb700b251dd3.png)
#
# **Output side called as  Aggregation**
#
#
# **What is bootstrap in random forest?**
# * When training, each tree in a random forest learns from a random sample of the data points. The samples are drawn with replacement, known as bootstrapping, which means that some samples will be used multiple times in a single tree.
#
#
#
#
# **For regression task it will take average**
#
#
#
# **For classification it will count the output**

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn.model_selection import train_test_split
from preprocessor import *
from imblearn.over_sampling import SMOTE
import warnings
warnings.filterwarnings('ignore')
from sklearn.metrics import accuracy_score,f1_score,classification_report
from sklearn.model_selection import GridSearchCV

# %%
df = pd.read_csv('HR.csv')

# %%
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
df.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %% [markdown]
# df.columns

# %% [markdown]
# ## Spliting The Data

# %%
x = df.drop('Attrition', axis=1) # Extract the features (all columns except Attritions) from the dataset

# %%
y = df['Attrition'].map({"No":0, "Yes":1}) # Extract the target variable from the dataset with converting 0 and 1.

# %%
# Spliting the data into train and test
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=33)

# %% [markdown]
# ## Loading Preprocessor

# %%
# Load a preprocessor object from a pickled file

with open('preprocessor.pkl', 'rb') as f:
    preprocessor=pickle.load(f)

# %%
preprocessor
# Out:
# ColumnTransformer(transformers=[('OHE columns', OneHotEncoder(),
#                                  ['BusinessTravel', 'Department',
#                                   'MaritalStatus', 'EducationField', 'Gender',
#                                   'JobRole']),
#                                 ('Label_encoder', ModifiedLabelEncoder(),
#                                  ['OverTime']),
#                                 ('Standard_scaler', StandardScaler(),
#                                  ['Age', 'DailyRate', 'DistanceFromHome',
#                                   'MonthlyRate', 'HourlyRate',
#                                   'NumCompaniesWorked', 'TotalWorkingYears',
#                                   'Traini...
#                                   'YearsSinceLastPromotion',
#                                   'YearsWithCurrManager',
#                                   'PercentSalaryHike']),
#                                 ('Pass_through',
# ...

# %% [markdown]
# # Transforming the data

# %%
processed_x_train = preprocessor.fit_transform(x_train)

# %%
processed_x_train
# Out:
# array([[1., 0., 0., ..., 3., 2., 3.],
#        [0., 0., 1., ..., 2., 3., 3.],
#        [0., 0., 1., ..., 3., 1., 3.],
#        ...,
#        [0., 1., 0., ..., 2., 3., 3.],
#        [0., 0., 1., ..., 3., 3., 4.],
#        [0., 0., 1., ..., 0., 2., 3.]])

# %%
# importing randomforest
from sklearn.ensemble import RandomForestClassifier
rfc = RandomForestClassifier() # creating instance of RFC class
rfc.fit(processed_x_train, y_train) # passing transformed training data
# Out:
# RandomForestClassifier()

# %% [markdown]
# # Validating The Model

# %%
# Transform the testing data using the preprocessor object or PipeLine
processed_x_test = preprocessor.transform(x_test)

# %%
# testing the model
y_predict = rfc.predict(processed_x_test)

# %%
# Checking the accuracy by comparing predicted and actual y_test data:
accuracy_score(y_test,y_predict)
# Out:
# 0.8478260869565217

# %%
# Checking the f1_score:
f1_score(y_test,y_predict)
# Out:
# 0.2222222222222222

# %%
print(classification_report(y_test,y_predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.99      0.92       306
#            1       0.80      0.13      0.22        62
#
#     accuracy                           0.85       368
#    macro avg       0.82      0.56      0.57       368
# weighted avg       0.84      0.85      0.80       368

# %% [markdown]
# # Hyperparameters Tunning of RandomForest

# %%
# Generating 5 numbers as num=5, ranging from 200 to 2000 
for x in np.linspace(start=200,stop=2000,num=5):
    print(x)
# Out:
# 200.0
# 650.0
# 1100.0
# 1550.0
# 2000.0

# %%
# to get integer number:
for x in np.linspace(start=200,stop=2000,num=5):
    print(int(x))
# Out:
# 200
# 650
# 1100
# 1550
# 2000

# %%
n_estimators = [int(x) for x in np.linspace(start=200,stop=2000,num=5)] # List Comprehension-using for loop in list
max_features= ['auto', 'sqrt', 'log2']
max_depth = [int(x) for x in np.linspace(10,110,num=5)]
max_depth.append(None)
min_samples_split = [5,10]   # minimum number of samples required to split an internal node
min_samples_leaf = [2,4]     # minimum number of samples required to be at a leaf node.

#dictionary for hyperparameters:
randomf_grid = {'n_estimators': n_estimators, 'max_features': max_features,
               'max_depth': max_depth, 'min_samples_split': min_samples_split,
               'min_samples_leaf': min_samples_leaf}

## Again Creating RFC instance and use it in GridSearchCV estimator:
rfc1 = RandomForestClassifier(random_state=42)
rf_cv = GridSearchCV(estimator=rfc1,scoring='f1', param_grid=randomf_grid, cv=3, verbose=2,n_jobs=-1)

# estimator--number of decision tree
# scoring--->performance matrix to check performance
# param_distribution-->hyperparametes(dictionary we created)
# n_iter--->Number of parameter settings that are sampled. n_iter trades off runtime vs quality of the solution.default=10
# cv------> number of flods
# verbose=Controls the verbosity: the higher, the more messages.
# n_jobs---->Number of jobs to run in parallel,-1 means using all processors.

# Now we need to fit the processed training data on randomsearch cv
rf_cv.fit(processed_x_train,y_train)
rf_best_params = rf_cv.best_params_  # it will give you best parameters
print(f"Best Parameters: {rf_best_params}") # printing  best parameters
# Out:
# Fitting 3 folds for each of 360 candidates, totalling 1080 fits
# Best Parameters: {'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 2000}

# %% [raw]
# Fitting 3 folds for each of 360 candidates, totalling 1080 fits
# Best Parameters: {'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 2000}

# %%
# passing best parameter to randomforest:
rfc2 = RandomForestClassifier(max_depth= 10, max_features='sqrt', min_samples_leaf=2, min_samples_split=5, n_estimators= 2000)
rfc2.fit(processed_x_train,y_train) # train with tune parameters
# Out:
# RandomForestClassifier(max_depth=10, min_samples_leaf=2, min_samples_split=5,
#                        n_estimators=2000)

# %%
# Predicting using the tunning ModeL:
y_pred = rfc2.predict(processed_x_test) # testing
accur = accuracy_score(y_test,y_pred) # checking performance
accur
# Out:
# 0.845108695652174

# %%
f1_score=f1_score(y_test,y_pred) # checking performance with f1 Score

# %%
f1_score
# Out:
# 0.19718309859154928

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.99      0.91       306
#            1       0.78      0.11      0.20        62
#
#     accuracy                           0.85       368
#    macro avg       0.81      0.55      0.56       368
# weighted avg       0.84      0.85      0.79       368
